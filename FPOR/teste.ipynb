# %%
from resources.msc_rafael_pavan import *

from optimizers.CLPSO import *

from optimizers.PSO import *

from optimizers.SQP_BB import *
sep = case118()
inicializa_sep(sep)

# from optimizers.MPI import *

# sep.gen['max_q_mvar'] = 500

# sep.gen['min_q_mvar'] = -500

# sep.ext_grid['max_q_mvar'] = 500

# sep.ext_grid['min_q_mvar'] = -500

# Interior_Points(sep)

# validacao(sep,cria_enxame(sep,1)[0])

a = Comprehensive_Learning_PSO(sep,0.9,0,1,0.05,150,40,1,0.1,0,0.1,0.4,0.9,True,False)
# Out:
# c:\Users\Rafael Pavan\Desktop\Mestrado\FPOR\resources\msc_rafael_pavan.py:116: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   matriz_z = np.zeros((9,len(sep.line.index.ravel())),dtype=np.float64)
# c:\Users\Rafael Pavan\Desktop\Mestrado\FPOR\resources\msc_rafael_pavan.py:120: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   g = np.zeros(len(sep.line.index.ravel()),dtype=np.float64)
# c:\Users\Rafael Pavan\Desktop\Mestrado\FPOR\resources\msc_rafael_pavan.py:129: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   for i in range(len(sep.line.index.ravel())):
# c:\Users\Rafael Pavan\Desktop\Mestrado\FPOR\resources\msc_rafael_pavan.py:165: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
# ...

# %%
pd.DataFrame(results['voltages']).to_csv('voltage_ieee118_1.csv')
pd.DataFrame(results['angles']).to_csv('angle_ieee118_1.csv')
pd.DataFrame([432]).to_csv('time_ieee118_1.csv')
pd.DataFrame(results['trafos']).to_csv('trafos_ieee118_1.csv')
pd.DataFrame(results['shunts']).to_csv('shunts_ieee118_1.csv')
pd.DataFrame(results['reactive_power']).to_csv('qpower_ieee118_1.csv')

# %%
from optimizers.SQP_BB import *

gbests = pd.read_csv('solutions_and_curves/CLPSO_IEEE118_2/gbest_ieee118_2.csv').values[:,1:]

t = []
a = []
tr = []
sh = []
rp = []
it = []
te = []
obj = []


for i in range(25):

    validacao(sep, gbests[i,:], False)

    try:
        
        s=time.time()
        
        results = Sequential_Quadratic_Programming_Branch_and_Bound(sep,0.02,0.02)
        
        e=time.time()
        
        t.append(results['voltages'])
        a.append(results['angles'])
        tr.append(results['trafos'])
        sh.append(results['shunts'])
        rp.append(results['reactive_power'])
        obj.append(results['objective_function'])
        it.append(results['iterations'])
        te.append(e-s)

    except:

        t.append(-1)
        a.append(-1)
        tr.append(-1)
        sh.append(-1)
        rp.append(-1)
        obj.append(-1)
        it.append(-1)
        te.append(-1)


# Particle_Swarm_Optimization(sep, 1e6, 1e6, 100, 40,2,2,0.1,0,0.1,0.4,0.9,True, False)
# Out:
# c:\Users\Rafael Pavan\Desktop\Mestrado\FPOR\resources\msc_rafael_pavan.py:116: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   matriz_z = np.zeros((9,len(sep.line.index.ravel())),dtype=np.float64)
# c:\Users\Rafael Pavan\Desktop\Mestrado\FPOR\resources\msc_rafael_pavan.py:120: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   g = np.zeros(len(sep.line.index.ravel()),dtype=np.float64)
# c:\Users\Rafael Pavan\Desktop\Mestrado\FPOR\resources\msc_rafael_pavan.py:129: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   for i in range(len(sep.line.index.ravel())):
# c:\Users\Rafael Pavan\Desktop\Mestrado\FPOR\resources\msc_rafael_pavan.py:165: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
# ...

# %%
pd.DataFrame([t]).to_csv('voltage_ieee118_2.csv')
pd.DataFrame([a]).to_csv('angle_ieee118_2.csv')
pd.DataFrame([te]).to_csv('time_ieee118_2.csv')
pd.DataFrame([tr]).to_csv('trafos_ieee118_2.csv')
pd.DataFrame([sh]).to_csv('shunts_ieee118_2.csv')
pd.DataFrame([rp]).to_csv('qpower_ieee118_2.csv')
pd.DataFrame([obj]).to_csv('obj_ieee118_2.csv')
pd.DataFrame([it]).to_csv('it_ieee118_2.csv')
pd.DataFrame([te]).to_csv('time_ieee118_2.csv')

# %%
fitness = pd.read_csv('solutions_and_curves/CLPSO_IEEE118_2/fitness_ieee118_2.csv').values[:,-1]
perdas = pd.read_csv('solutions_and_curves/CLPSO_IEEE118_2/perdas_ieee118_2.csv').values[:,-1]

a = (fitness-perdas)

hib = pd.read_csv('solutions_and_curves/CLPSO_SQP_BB_IEEE118_2/obj_ieee118_2.csv').values


filtropositivo = np.where(hib[0][1:]>0)

fac = []
listacl= []

listah= []
for i in range(25):

    if a[i]>1e-6:

        if hib[0][i]>0:

            fac.append(hib[0][i])
            listah.append(i)

    else:
        
        if hib[0][i]<0:

            fac.append(perdas[i])
            listacl.append(i)
        
        else: 
            fac.append(hib[0][i])
            listah.append(i)

# %%
np.mean(it)
# Out:
# 26.04

# %%
per = []

fitn = []

penv = []

penq = []

gbest = []

tempos = []

for i in range(25):
    
    j, perdas, pen_v, pen_gq, pen_tap, pen_bsh, global_best, tempo = Comprehensive_Learning_PSO(sep,0.9,0,1e3,1e3,100,40,1,0.1,0,0.1,0.4,0.9,False,False)  
    print(i)
    per.append(perdas)
    fitn.append(j)
    penv.append(pen_v)
    penq.append(pen_gq)
    gbest.append(global_best)
    tempos.append(tempo)
    print(fitn[-1][-1], per[-1][-1])
# Out:
# c:\Users\Rafael Pavan\Desktop\Mestrado\FPOR\resources\msc_rafael_pavan.py:116: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   matriz_z = np.zeros((9,len(sep.line.index.ravel())),dtype=np.float64)
# c:\Users\Rafael Pavan\Desktop\Mestrado\FPOR\resources\msc_rafael_pavan.py:120: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   g = np.zeros(len(sep.line.index.ravel()),dtype=np.float64)
# c:\Users\Rafael Pavan\Desktop\Mestrado\FPOR\resources\msc_rafael_pavan.py:129: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   for i in range(len(sep.line.index.ravel())):
# c:\Users\Rafael Pavan\Desktop\Mestrado\FPOR\resources\msc_rafael_pavan.py:165: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
# ...

# %%
for val in t:

    if val == -1:

        print(val)
# Out:
# -1
# -1
# -1
# -1
# -1
# -1

# %%
import pandas as pd

pd.DataFrame(per).to_csv('perdas_ieee118_1.csv')

pd.DataFrame(fitn).to_csv('fitness_ieee118_1.csv')

pd.DataFrame(penq).to_csv('penq_ieee118_1.csv')

pd.DataFrame(penv).to_csv('penq_ieee118_1.csv')

pd.DataFrame(gbest).to_csv('gbest_ieee118_1.csv')

pd.DataFrame(tempos).to_csv('tempos_ieee118_1.csv')

# %%
gbests = pd.read_csv('solutions_and_curves/CLPSO_IEEE118_2/gbest_ieee118_2.csv').values[5,1:]

gbests
# Out:
# array([ 1.05767942e+00,  9.96663819e-01,  1.02923723e+00,  1.01849799e+00,
#         1.04846445e+00,  1.04143870e+00,  1.01841061e+00,  1.01025810e+00,
#         1.01306050e+00,  1.00865508e+00,  1.03154663e+00,  1.05190748e+00,
#         1.03930749e+00,  1.02179541e+00,  1.01479070e+00,  1.02057857e+00,
#         1.02394157e+00,  1.02045698e+00,  1.01931290e+00,  1.02202409e+00,
#         1.02151962e+00,  1.03709718e+00,  1.01688820e+00,  1.01271652e+00,
#         1.01392199e+00,  1.02497707e+00,  1.01958414e+00,  1.01530967e+00,
#         1.03425068e+00,  1.03849174e+00,  1.02443849e+00,  1.01140238e+00,
#         1.02935162e+00,  9.98106425e-01,  9.82268886e-01,  1.01960580e+00,
#         1.03123220e+00,  1.02218408e+00,  1.00968226e+00,  1.04397350e+00,
#         1.02636691e+00,  1.03043694e+00,  1.02839088e+00,  1.01787660e+00,
#         1.03457907e+00,  1.02570943e+00,  1.01333920e+00,  1.01458037e+00,
# ...

# %%
vbus, theta, v_lim_superior, v_lim_inferior = coleta_dados_vbus(sep,False)
matriz_g, matriz_z = matriz_condutancia(sep, False)
func_objetivo(vbus,theta,matriz_g,matriz_z)
# Out:
# +---------------------------------+---------------------------------+
# |   Perdas Totais Nas Linhas (pu) |   Perdas Totais Nas Linhas (MW) |
# |---------------------------------+---------------------------------|
# |                         1.20569 |                         120.569 |
# +---------------------------------+---------------------------------+

# %%
clpso = pd.read_csv('solutions_and_curves/CLPSO_IEEE118_1/tempos_ieee118_1.csv').values[:,:]
clpso_sqpbb = pd.read_csv('solutions_and_curves/CLPSO_SQP_BB_IEEE118_1/it_ieee118_1.csv').values[:,1:]
# hibrido = pd.read_csv('solutions_and_curves/CLPSO_SQP_BB_IEEE118_1/trafos_ieee118_1.csv').values[:,1:]
# hibrido = np.array([0.98, 1.1, 0.98, 0.98, 0.98, 1.0, 0.97, 1.0, 0.95, 1.0, 0.98, 1.0, 1.0])

f = np.where(clpso_sqpbb[0]<0)
plt.scatter(np.arange(1,10,1),clpso[55:55+9], label='CLPSO', facecolors='none', color='blue')
plt.scatter(np.arange(1,10,1),hibrido[filter], label='CLPSO-SQP-BB', marker='x', color='purple')
for val in np.arange(0.9,1.1,0.01):

    plt.plot(np.arange(1,10,0.25),np.ones(36)*val, '_', color='black', alpha=0.4)


plt.ylim((0.9,1.1))
plt.yticks(np.arange(0.88,1.12,0.02))
plt.xticks(np.arange(1,10,1))
plt.legend(loc='upper right',fontsize=12)
plt.xlabel('Transformador', fontsize=12)
plt.ylabel('$tap$ ($pu$)', fontsize=12)
plt.xlim((0.8,9.2))

plt.show()

clpso_sqpbb[0][clpso_sqpbb[0]>0].mean()
# Out:
# 148.4

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams['axes.linewidth'] = 2
clpso = pd.read_csv('solutions_and_curves/CLPSO_IEEE118_1/gbest_ieee118_1.csv').values[11,1:]

# clpso_sqpbb = pd.read_csv('solutions_and_curves/CLPSO_SQP_BB_IEEE118_1/obj_ieee118_1.csv').values[:,1:]

# hibrido = pd.read_csv('solutions_and_curves/CLPSO_SQP_BB_IEEE118_1/voltage_ieee118_1.csv').values[11,1:]

# h[filter]
# plt.scatter(np.arange(1,10,1),clpso[54:54+9], label='CLPSO', facecolors='none', color='blue')
# plt.scatter(np.arange(1,10,1),h[filter], label='CLPSO-SQP-BB', marker='x', color='purple')

# for val in np.arange(0.9,1.1,0.01):

#     plt.plot(np.arange(1,10,0.25),np.ones(36)*val, '_', color='black', alpha=0.4)



# plt.yticks(np.arange(0.88,1.12,0.02))
# plt.ylim((0.89,1.109))
# plt.xticks(np.arange(1,10,1))
# plt.legend(loc='upper right',fontsize=12)
# plt.xlabel('Transformador', fontsize=12)
# plt.ylabel('$tap$ ($pu$)', fontsize=12)
# plt.xlim((0.8,9.2))

# plt.show()

# # filter = sep.shunt['bus'].values.tolist()

# %%
validacao(sep, clpso)
# Out:
# c:\Users\Rafael Pavan\Desktop\Mestrado\FPOR\resources\msc_rafael_pavan.py:116: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   matriz_z = np.zeros((9,len(sep.line.index.ravel())),dtype=np.float64)
# c:\Users\Rafael Pavan\Desktop\Mestrado\FPOR\resources\msc_rafael_pavan.py:120: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   g = np.zeros(len(sep.line.index.ravel()),dtype=np.float64)
# c:\Users\Rafael Pavan\Desktop\Mestrado\FPOR\resources\msc_rafael_pavan.py:129: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
#   for i in range(len(sep.line.index.ravel())):
# c:\Users\Rafael Pavan\Desktop\Mestrado\FPOR\resources\msc_rafael_pavan.py:165: FutureWarning: Index.ravel returning ndarray is deprecated; in a future version this will return a view on self.
# ...

# %%
sep.trafo
filter=[0,1,2,3,4,5,6,8,10]

# %%
# Out:
# [4, 33, 36, 43, 44, 45, 47, 73, 78, 81, 82, 104, 106, 109]

# %%
a = pd.read_csv('solutions_and_curves/CLPSO_IEEE118_1/perdas_ieee118_1.csv').values[:,1:]
b = pd.read_csv('solutions_and_curves/PSO_IEEE118_1/perdas_ieee118_1.csv').values[:,1:]
c = pd.read_csv('solutions_and_curves/CLPSO_IEEE118_2/perdas_ieee118_2.csv').values[:,1:]

a = a.mean(axis=0)*100

b = b.mean(axis=0)*100

c = c[np.where(aa<1e-6),:][0].mean(axis=0)*100

c

clpso = []

clpso2 = []

pso = []
iterations = []

for i in range(len(a)):

    if i%5==0:

        clpso.append(a[i])
        clpso2.append(c[i])
        iterations.append(i)
        pso.append(b[i])

iterations.append(100)
clpso.append(clpso[-1])
pso.append(pso[-1])
clpso2.append(clpso2[-1])

# %%
# Out:
# array([[1.20866058, 1.21217602, 1.21542171, 1.22078714, 1.2176344 ,
#         1.20739977, 1.21192081, 1.20651864, 1.20731456, 1.20924481,
#         1.20364582, 1.21630757, 1.20836499, 1.20798202]])

# %%
plt.rcParams['font.family'] = 'serif'
plt.rcParams['axes.linewidth'] = 2
plt.plot(iterations,pso, '-^', color='red', label='PSO')
plt.plot(iterations,clpso, '-o', color='Blue', label='CLPSO')
plt.ylim((116, 150))
plt.yticks(np.arange(118,151,3))
plt.xlabel('Iteração', fontsize=12)
plt.ylabel('Perdas (MW)', fontsize=12)
plt.legend(fontsize=12)
plt.show()

# %%
from pandapower.networks import case1354pegase

sep = case1354pegase()

sep.bus
# Out:
#       in_service  max_vm_pu  min_vm_pu  name type  vn_kv zone
# 0           True        1.1        0.9     2    b  220.0  0.0
# 1           True        1.1        0.9     3    b  220.0  0.0
# 2           True        1.1        0.9     9    b  220.0  0.0
# 3           True        1.1        0.9    20    b  220.0  0.0
# 4           True        1.1        0.9    21    b  220.0  0.0
# ...          ...        ...        ...   ...  ...    ...  ...
# 1349        True        1.1        0.9  9212    b  380.0  0.0
# 1350        True        1.1        0.9  9216    b  220.0  0.0
# 1351        True        1.1        0.9  9221    b  380.0  0.0
# 1352        True        1.1        0.9  9230    b  220.0  0.0
# 1353        True        1.1        0.9  9240    b  220.0  0.0
#
# [1354 rows x 7 columns]

# %%
caso1 = pd.read_csv('solutions_and_curves/CLPSO_SQP_BB_IEEE118_1/obj_ieee118_1.csv').values[:,1:][0]
caso2 = pd.read_csv('solutions_and_curves/CLPSO_SQP_BB_IEEE118_2/obj_ieee118_2.csv').values[:,1:][0]

# %%
# caso 1 11
# caso 2 7
caso1 = pd.read_csv('solutions_and_curves/CLPSO_SQP_BB_IEEE118_1/voltage_ieee118_1.csv').values[:,1:]
caso2 = pd.read_csv('solutions_and_curves/CLPSO_SQP_BB_IEEE118_2/voltage_ieee118_2.csv').values[:,1:]

# %%
caso1 = np.array([1.0412663532, 1.0415051737, 1.0434200112, 1.05938729, 1.06, 1.052151168, 1.0505093104, 1.0442637624, 1.06, 1.0530037055, 1.0459290237, 1.0494522727, 1.0342937459, 1.0483255016, 1.0482797891, 1.0457505861, 1.0598440716, 1.0507932713, 1.0474952006, 1.035887994, 1.0312072232, 1.0350385857, 1.0513347674, 1.0520299154, 1.06, 1.06, 1.0456632451, 1.0387443986, 1.0387827615, 1.0568487713, 1.0416975239, 1.0443222138, 1.0460011186, 1.0567617734, 1.0544932644, 1.0548792243, 1.06, 1.0540071786, 1.0376025677, 1.0356486741, 1.0295543446, 1.0375133104, 1.0406937938, 1.0318264072, 1.0293527643, 1.0470539196, 1.0532460698, 1.0546741246, 1.06, 1.0487641049, 1.0309155021, 1.0252002298, 1.0245872885, 1.0392090688, 1.0382205113, 1.0384878956, 1.040050991, 1.0320854408, 1.06, 1.0577678515, 1.06, 1.0560634097, 1.0499908799, 1.0575926118, 1.06, 1.06, 1.0522324464, 1.0597651213, 1.06, 1.0375421452, 1.0383284951, 1.0418542803, 1.0371364118, 1.0274104715, 1.0283622718, 1.0251580277, 1.0472825274, 1.0421705104, 1.0425410969, 1.06, 1.0581070853, 1.0378723653, 1.0411522688, 1.0493189935, 1.06, 1.0512549805, 1.0593118466, 1.0514570754, 1.06, 1.0438016384, 1.0487660524, 1.06, 1.0458466672, 1.0409237966, 1.0289681332, 1.0365910882, 1.0438359524, 1.0525239605, 1.0551479661, 1.06, 1.0473623453, 1.0547619695, 1.0517800819, 1.0432978584, 1.0394731051, 1.0317053143, 1.0264600198, 1.0363404405, 1.0352747577, 1.0358341688, 1.043744326, 1.0202529534, 1.0577807476, 1.0403770599, 1.0400819017, 1.06, 1.0345578696, 1.0208646667])
caso2 = np.array([[1.0281720379, 1.0362212195, 1.035445068, 1.0595767878, 1.06, 1.0520192745, 1.0502574762, 1.0451612277, 1.06, 1.0520754204, 1.0455875337, 1.0490024573, 1.0334485391, 1.0473343721, 1.0458087857, 1.0444204031, 1.0566615768, 1.049331051, 1.0450494582, 1.0339714057, 1.0296885852, 1.033992892, 1.0510765778, 1.0521158075, 1.06, 1.06, 1.044968498, 1.0378292047, 1.0376345381, 1.06, 1.0404704718, 1.0434746895, 1.0446702249, 1.0569277334, 1.0546588227, 1.0550786788, 1.06, 1.0550453457, 1.0376736059, 1.0357596115, 1.0296459908, 1.0375493266, 1.0410620884, 1.0324754723, 1.0300909578, 1.0470391774, 1.0532307737, 1.0546713893, 1.06, 1.0486905198, 1.0307993427, 1.0250989588, 1.0245347597, 1.0391950753, 1.0381753868, 1.0382002834, 1.0398507815, 1.0318952768, 1.06, 1.057770368, 1.06, 1.0560845005, 1.0521563487, 1.0551591804, 1.06, 1.06, 1.0522431103, 1.0583329744, 1.06, 1.0366906504, 1.0381541216, 1.0420690391, 1.0377322853, 1.0131922095, 1.0171079803, 1.0008996504, 1.0434251821, 1.0383887206, 1.0389540812, 1.06, 1.0571932949, 1.0323305613, 1.0343222317, 1.0394270406, 1.0487456267, 1.0443357989, 1.06, 1.0468294826, 1.06, 1.0434344306, 1.0479742611, 1.0488676518, 1.0381749478, 1.0364084564, 1.0246469575, 1.0326197434, 1.0417901037, 1.0525243502, 1.0551398992, 1.06, 1.0424111233, 1.0456305496, 1.0517816169, 1.0407258118, 1.037856339, 1.0306016937, 1.0262617829, 1.0343115395, 1.0330783405, 1.0332048951, 1.0435899714, 1.0193594387, 1.0558634409, 1.039589177, 1.0393045988, 1.0554330422, 1.0340988927, 1.0034076758]])


# plt.figure(figsize=(6.5,6))
filter = sep.shunt['bus'].values
plt.rcParams['axes.linewidth'] = 2
plt.rcParams["font.family"] = "serif"
plt.scatter(np.arange(1,119,1),caso1, label='CLPSO-SQP-BB (caso 1)', marker='o', facecolors='none',color='blue')
plt.scatter(np.arange(1,119,1),caso2, label='CLPSO-SQP-BB (caso 2)',  marker='s', facecolors='none',color='green')

# # for val in np.arange(-0.25,0.16,0.01):

# #     plt.plot(np.arange(1,15,0.5),np.ones(28)*val, '_', color='black', alpha=0.4)


# # # # plt.yticks(np.arange(0.88,1.12,0.02))
plt.ylim((0.935,1.065))
plt.yticks(np.arange(0.94,1.06,0.02))
plt.legend(loc='lower right',fontsize=12)
plt.xlabel('Barra', fontsize=12)
plt.ylabel('Magnitude de Tensão (V)', fontsize=12)
plt.xticks(np.arange(1,119,13))
# # plt.xlim((0.5,14.42))
# legend = plt.legend()
# # legend.get_frame().set_edgecolor('1.0')
# plt.show()
# Out:
# ([<matplotlib.axis.XTick at 0x1a679d00d00>,
# ...
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
plt.plot(sep.line['max_i_ka'].values)
plt.plot(sep.res_line['i_from_ka'].values)

# %%
a = caso2[filter]
b=sep.gen['max_q_mvar'].values
c=sep.gen['min_q_mvar'].values

# %%
x = np.arange(1,250)
y = 0.025*np.exp((x**2)/1e4)

y
# Out:
# array([ 0.0250025 ,  0.02501   ,  0.02502251,  0.02504003,  0.02506258,
#         0.02509016,  0.0251228 ,  0.02516051,  0.02520332,  0.02525125,
#         0.02530434,  0.0253626 ,  0.02542609,  0.02549483,  0.02556888,
#         0.02564826,  0.02573304,  0.02582326,  0.02591899,  0.02602027,
#         0.02612717,  0.02623976,  0.02635811,  0.02648228,  0.02661236,
#         0.02674843,  0.02689057,  0.02703888,  0.02719344,  0.02735436,
#         0.02752173,  0.02769566,  0.02787627,  0.02806367,  0.02825798,
#         0.02845932,  0.02866784,  0.02888365,  0.02910692,  0.02933777,
#         0.02957637,  0.02982288,  0.03007745,  0.03034027,  0.0306115 ,
#         0.03089134,  0.03117997,  0.03147759,  0.03178441,  0.03210064,
#         0.03242649,  0.03276221,  0.03310803,  0.03346419,  0.03383094,
#         0.03420856,  0.03459731,  0.03499747,  0.03540935,  0.03583324,
#         0.03626945,  0.03671832,  0.03718018,  0.03765538,  0.03814428,
# ...
